# %% [markdown]
# <a href="https://colab.research.google.com/github/Shibata-1273352/skillupai/blob/master/Lecture2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded_file = files.upload()
# Out:
#      <input type="file" id="files-97d998ca-c2ef-4887-98fc-58c5fd0d4a8f" name="files[]" multiple disabled />
#      <output id="result-97d998ca-c2ef-4887-98fc-58c5fd0d4a8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 00.jpg to 00.jpg

# %%
uploaded_file_name = next(iter(uploaded_file))
print(uploaded_file_name)
# Out:
# 00.jpg

# %%
import cv2
orig = cv2.imread(uploaded_file_name)
src = cv2.cvtColor(orig, cv2.COLOR_BGR2RGB)

# %%
from matplotlib import pyplot as plt

plt.imshow(src)

# %%
blurred = cv2.blur(src, (20, 20))
plt.imshow(blurred)
